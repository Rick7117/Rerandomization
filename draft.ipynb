# %%
import numpy as np
import pandas as pd
from functions_for_simulation import *

# %%
Xs = Xs_generator(rowNum=200, colNum=400)
Xs
# Out:
#            x0        x1        x2        x3        x4        x5        x6  \
# 0    1.167347  0.151666 -0.918396 -0.271479  1.211077  1.491461  0.586511
# 1   -0.212072 -0.849130 -0.068623  0.484677  0.234738  0.872109  0.530374
# 2    1.134042  0.843421 -0.892205  1.044864 -1.725164  0.500002 -1.562384
# 3   -2.197752 -1.020547 -0.203853 -0.079188  0.934012 -0.740985 -0.416488
# 4   -1.602277  0.711193 -0.010856 -0.262134 -0.221836  1.848755 -0.640326
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.235281  0.515178  0.847707  0.323375 -1.499254  0.216035 -0.685309
# 196  0.408074 -0.481093  1.649827  1.539635 -0.444280 -0.875557 -1.039821
# 197 -0.580009 -2.187804  0.612737 -0.896731  0.184042 -1.349820  1.194102
# 198 -1.433523 -0.530215 -0.222476  0.251552 -0.362237  0.535556 -0.215896
# 199 -0.241158  0.976275  1.274388 -0.816723  1.575949 -1.214633 -1.054735
#
#            x7        x8        x9  ...      x390      x391      x392  \
# ...

# %%
Ws = np.ones(200)
df = Ys_generator(Xs, Ws, 0.5)
Xs
# Out:
#            x0        x1        x2        x3        x4        x5        x6  \
# 0    1.167347  0.151666 -0.918396 -0.271479  1.211077  1.491461  0.586511
# 1   -0.212072 -0.849130 -0.068623  0.484677  0.234738  0.872109  0.530374
# 2    1.134042  0.843421 -0.892205  1.044864 -1.725164  0.500002 -1.562384
# 3   -2.197752 -1.020547 -0.203853 -0.079188  0.934012 -0.740985 -0.416488
# 4   -1.602277  0.711193 -0.010856 -0.262134 -0.221836  1.848755 -0.640326
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.235281  0.515178  0.847707  0.323375 -1.499254  0.216035 -0.685309
# 196  0.408074 -0.481093  1.649827  1.539635 -0.444280 -0.875557 -1.039821
# 197 -0.580009 -2.187804  0.612737 -0.896731  0.184042 -1.349820  1.194102
# 198 -1.433523 -0.530215 -0.222476  0.251552 -0.362237  0.535556 -0.215896
# 199 -0.241158  0.976275  1.274388 -0.816723  1.575949 -1.214633 -1.054735
#
#            x7        x8        x9  ...      x390      x391      x392  \
# ...

# %%
df_filtered = df[df.columns[df.columns.str.contains('x')]]
df_filtered.columns
# Out:
# Index(['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9',
#        ...
#        'x390', 'x391', 'x392', 'x393', 'x394', 'x395', 'x396', 'x397', 'x398',
#        'x399'],
#       dtype='object', length=400)

# %%
Mahalanobis_distance(Xs, Ws)
# cov_X = np.cov(Xs)
# n = len(Ws)
# pw = np.sum(Ws) / n
# print(Xs.shape)
# print(cov_X.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Mahalanobis_distance(Xs, Ws)
#       2 # cov_X = np.cov(Xs)
#       3 # n = len(Ws)
#       4 # pw = np.sum(Ws) / n
#       5 # print(Xs.shape)
#       6 # print(cov_X.shape)
#
# File d:\Python\Rerandomization\functions_for_simulation.py:67, in Mahalanobis_distance(Xs, Ws)
#      65 n = len(Ws)
#      66 pw = np.sum(Ws) / n
# ---> 67 diff_T_C = Xs @ (Ws - np.ones(n) * pw) / (n * pw * (1 - pw))
#      68 print(diff_T_C.shape)
#      69 print(cov_X.shape)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:1775, in DataFrame.__matmul__(self, other)
#    1771 def __matmul__(self, other: AnyArrayLike | DataFrame) -> DataFrame | Series:
#    1772     """
# ...

# %%
Xs.cov
# Out:
# <bound method DataFrame.cov of            x0        x1        x2        x3        x4        x5        x6  \
# 0   -1.111051 -0.335438 -0.196432 -3.136527  0.636103 -0.326304  0.955534
# 1    0.038884  0.392361 -0.325006 -1.038601 -1.915163 -0.124809 -1.837524
# 2   -0.725580  2.127997 -0.644305  0.236981 -0.791357 -1.665610  1.689445
# 3   -1.602517 -0.257299 -0.598473  0.963777  0.323543 -0.774948  0.178028
# 4   -0.285212  0.873529 -0.525048 -0.019266  0.080552 -1.043279  0.453261
# ..        ...       ...       ...       ...       ...       ...       ...
# 195 -0.818595 -1.564059 -2.379185 -0.456104  0.722963 -0.864689 -0.410997
# 196  0.633429 -0.891271  0.057079  0.679916  0.714482 -0.774728 -0.807027
# 197  1.196182 -0.361129  0.898956  0.217669  0.478898  0.415182 -1.405305
# 198 -0.308657 -0.968997  1.105288  0.892820  2.270104  0.518829  0.217762
# 199 -2.226072  1.308324 -1.312018  0.138309 -0.511881  1.282624 -0.568592
#
# ...
