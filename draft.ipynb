# %%
import numpy as np
import pandas as pd
from functions_for_simulation import *

# %%
Xs = Xs_generator(rowNum=200, colNum=400)
Xs
# Out:
#            x0        x1        x2        x3        x4        x5        x6  \
# 0   -3.547232 -1.598378 -1.626361 -1.086392  0.908901  0.534229  0.909343
# 1   -0.734906 -0.659393 -1.377107 -0.403185 -1.318640 -0.503749  1.251575
# 2   -0.728314  1.841763  0.608920 -0.096262  2.792644 -1.366840  0.029762
# 3    0.663197  0.792825 -0.382982  1.208114 -2.212725 -0.522932  0.329719
# 4    0.181483  0.921658  0.216684 -1.138249  0.794613 -0.037617  0.036742
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  3.467700 -0.483008  0.637480  0.502460 -1.073429 -2.464724 -1.869213
# 196 -0.197355  0.468431 -0.685904  0.910602 -0.401380 -2.599462 -0.654266
# 197  1.008822  2.732542  1.082279  0.927162 -0.001000 -1.134073  0.392682
# 198 -0.381005 -3.983305  0.906753  0.752211  0.775460  0.538732 -0.553786
# 199 -0.427347  1.654300 -1.359452  0.436911 -0.306624  2.513495 -0.821861
#
#            x7        x8        x9  ...      x390      x391      x392  \
# ...

# %%
Ws = np.ones(200)
Ys = Ys_generator(Xs, Ws, 0.5)
print(Ys)
# Out:
# None
